# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn.utils import resample
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier

from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline

# %%
X = pd.read_csv('references/training_set_values.csv', index_col = 'id')
y = pd.read_csv('references/training_set_labels.csv', index_col = 'id')['status_group']
df = X.copy()
df['target'] = y.copy()

# %%
df['target'].value_counts()
# Out:
# functional                 32259
# non functional             22824
# functional needs repair     4317
# Name: target, dtype: int64

# %%
# df.drop[col = ['num_private'], inplace = True]

# %%
df.head()
# Out:
#        amount_tsh date_recorded        funder  gps_height     installer  \
# id
# 69572      6000.0    2011-03-14         Roman        1390         Roman
# 8776          0.0    2013-03-06       Grumeti        1399       GRUMETI
# 34310        25.0    2013-02-25  Lottery Club         686  World vision
# 67743         0.0    2013-01-28        Unicef         263        UNICEF
# 19728         0.0    2011-07-13   Action In A           0       Artisan
#
#        longitude   latitude              wpt_name  num_private  \
# id
# 69572  34.938093  -9.856322                  none            0
# 8776   34.698766  -2.147466              Zahanati            0
# 34310  37.460664  -3.821329           Kwa Mahundi            0
# 67743  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 19728  31.130847  -1.825359               Shuleni            0
#
#                          basin  ... water_quality quality_group      quantity  \
# id                              ...
# 69572               Lake Nyasa  ...          soft          good        enough
# 8776             Lake Victoria  ...          soft          good  insufficient
# 34310                  Pangani  ...          soft          good        enough
# 67743  Ruvuma / Southern Coast  ...          soft          good           dry
# 19728            Lake Victoria  ...          soft          good      seasonal
#
#        quantity_group                source           source_type  \
# id
# 69572          enough                spring                spring
# 8776     insufficient  rainwater harvesting  rainwater harvesting
# 34310          enough                   dam                   dam
# 67743             dry           machine dbh              borehole
# 19728        seasonal  rainwater harvesting  rainwater harvesting
#
#        source_class              waterpoint_type waterpoint_type_group  \
# id
# 69572   groundwater           communal standpipe    communal standpipe
# 8776        surface           communal standpipe    communal standpipe
# 34310       surface  communal standpipe multiple    communal standpipe
# 67743   groundwater  communal standpipe multiple    communal standpipe
# 19728       surface           communal standpipe    communal standpipe
#
#                target
# id
# 69572      functional
# 8776       functional
# 34310      functional
# 67743  non functional
# 19728      functional
#
# [5 rows x 40 columns]

# %% [markdown]
# # Basic FSM

# %% [markdown]
# A basic logistic regression model that does not have anything applied to it other than a max_iter to keep errors from popping up.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, test_size = 0.25)

# %%
X_train_num = X_train.select_dtypes(exclude = ['object'])
lg = LogisticRegression(max_iter = 1000)
lg.fit(X_train_num, y_train)
cross_val_score(lg, X_train_num, y_train, cv = 5)
# Out:
# array([0.55566779, 0.55185185, 0.54848485, 0.54893378, 0.55252525])

# %% [markdown]
# The basic FSM has an r<sup>2</sup> score of around 0.55

# %%
X['construction_year'].replace({0: np.nan}, inplace = True)

# %%
X.isna().sum()
# Out:
# amount_tsh                   0
# date_recorded                0
# funder                    3635
# gps_height                   0
# installer                 3655
# longitude                    0
# latitude                     0
# wpt_name                     0
# num_private                  0
# basin                        0
# subvillage                 371
# region                       0
# region_code                  0
# district_code                0
# lga                          0
# ward                         0
# population                   0
# public_meeting            3334
# recorded_by                  0
# scheme_management         3877
# scheme_name              28166
# permit                    3056
# construction_year        20709
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# payment_type                 0
# water_quality                0
# quality_group                0
# quantity                     0
# quantity_group               0
# source                       0
# source_type                  0
# source_class                 0
# waterpoint_type              0
# waterpoint_type_group        0
# dtype: int64

# %%
# keep nans in construction year; create a new column that marks if it's nan or not
# decision tree

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, test_size = 0.25)
X_train_num = X_train.select_dtypes(exclude = ['object'])
X_test_num = X_test.select_dtypes(exclude = ['object'])

# %%
si = SimpleImputer()
X_train_num_si = pd.DataFrame(si.fit_transform(X_train_num), index = X_train_num.index, columns = X_train_num.columns)
X_train_num_si['construction_year'].value_counts()
# Out:
# 0.0       15463
# 2010.0     2001
# 2008.0     1959
# 2009.0     1892
# 2000.0     1595
# 2007.0     1195
# 2006.0     1103
# 2003.0      989
# 2011.0      943
# 2012.0      839
# 2004.0      823
# 2002.0      790
# 1978.0      787
# 1995.0      750
# 1998.0      745
# 1999.0      744
# 1990.0      741
# 2005.0      740
# 1985.0      685
# 1980.0      629
# 1996.0      613
# 1984.0      600
# 1982.0      571
# 1994.0      556
# 1972.0      515
# 1974.0      505
# 1997.0      484
# 1992.0      482
# 1993.0      463
# 2001.0      403
# 1988.0      398
# 1983.0      361
# 1975.0      326
# 1986.0      324
# 1970.0      293
# 1976.0      292
# 1991.0      236
# 1989.0      223
# 1987.0      219
# 1981.0      172
# 1977.0      156
# 1979.0      150
# 1973.0      142
# 2013.0      129
# 1971.0      112
# 1960.0       79
# 1963.0       72
# 1967.0       65
# 1968.0       57
# 1969.0       44
# 1964.0       28
# 1962.0       24
# 1961.0       15
# 1966.0       14
# 1965.0       14
# Name: construction_year, dtype: int64

# %% [markdown]
# # Upsampling Scratchwork

# %%
# df_0 = df[df.target == 'functional']
# df_1 = df[df.target == 'functional needs repair']
# df_2 = df[df.target == 'non functional']

# df_1_upsample = resample(df_1, replace = True, n_samples = 32259, random_state = 42)
# df_2_upsample = resample(df_2, replace = True, n_samples = 32259, random_state = 42)
# df_up = pd.concat([df_0, df_1_upsample, df_2_upsample])

# %%
# df['target'].value_counts()
# Out:
# functional                 32259
# non functional             22824
# functional needs repair     4317
# Name: target, dtype: int64

# %%
# df_up['target'].value_counts()
# Out:
# functional needs repair    32259
# non functional             32259
# functional                 32259
# Name: target, dtype: int64

# %%
# X_train, X_test, y_train, y_test = train_test_split(df_up.drop(columns = ['target']), df_up['target'], random_state = 42, test_size = 0.25)
# X_train_num = X_train.select_dtypes(exclude = ['object'])
# lg = LogisticRegression(max_iter = 1000)
# lg.fit(X_train_num, y_train)
# cross_val_score(lg, X_train_num, y_train, cv = 5)
# Out:
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-ccb1fcca8b0c> in <module>
#       3 lg = LogisticRegression(max_iter = 1000)
#       4 lg.fit(X_train_num, y_train)
# ----> 5 cross_val_score(lg, X_train_num, y_train, cv = 5)
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     404                                 fit_params=fit_params,
#     405                                 pre_dispatch=pre_dispatch,
# --> 406                                 error_score=error_score)
#     407     return cv_results['test_score']
#     408
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     246             return_times=True, return_estimator=return_estimator,
#     247             error_score=error_score)
# --> 248         for train, test in cv.split(X, y, groups))
#     249
#     250     zipped_scores = list(zip(*scores))
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1027             # remaining jobs.
#    1028             self._iterating = False
# -> 1029             if self.dispatch_one_batch(iterator):
#    1030                 self._iterating = self._original_iterator is not None
#    1031
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\joblib\parallel.py in __call__(self)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     529             estimator.fit(X_train, **fit_params)
#     530         else:
# --> 531             estimator.fit(X_train, y_train, **fit_params)
#     532
#     533     except Exception as e:
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1415                       penalty=penalty, max_squared_sum=max_squared_sum,
#    1416                       sample_weight=sample_weight)
# -> 1417             for class_, warm_start_coef_ in zip(classes_, warm_start_coef))
#    1418
#    1419         fold_coefs_, _, n_iter_ = zip(*fold_coefs_)
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1027             # remaining jobs.
#    1028             self._iterating = False
# -> 1029             if self.dispatch_one_batch(iterator):
#    1030                 self._iterating = self._original_iterator is not None
#    1031
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\joblib\parallel.py in __call__(self)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio)
#     758                 func, w0, method="L-BFGS-B", jac=True,
#     759                 args=(X, target, 1. / C, sample_weight),
# --> 760                 options={"iprint": iprint, "gtol": tol, "maxiter": max_iter}
#     761             )
#     762             n_iter_i = _check_optimize_result(
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     616     elif meth == 'l-bfgs-b':
#     617         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 618                                 callback=callback, **options)
#     619     elif meth == 'tnc':
#     620         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_and_grad(self, x)
#     198         if not np.array_equal(x, self.x):
#     199             self._update_x_impl(x)
# --> 200         self._update_fun()
#     201         self._update_grad()
#     202         return self.f, self.g
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\scipy\optimize\_differentiable_functions.py in _update_fun(self)
#     164     def _update_fun(self):
#     165         if not self.f_updated:
# --> 166             self._update_fun_impl()
#     167             self.f_updated = True
#     168
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\scipy\optimize\_differentiable_functions.py in update_fun()
#      71
#      72         def update_fun():
# ---> 73             self.f = fun_wrapped(self.x)
#      74
#      75         self._update_fun_impl = update_fun
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_wrapped(x)
#      68         def fun_wrapped(x):
#      69             self.nfev += 1
# ---> 70             return fun(x, *args)
#      71
#      72         def update_fun():
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\scipy\optimize\optimize.py in __call__(self, x, *args)
#      72     def __call__(self, x, *args):
#      73         """ returns the the function value """
# ---> 74         self._compute_if_needed(x, *args)
#      75         return self._value
#      76
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\scipy\optimize\optimize.py in _compute_if_needed(self, x, *args)
#      66         if not np.all(x == self.x) or self._value is None or self.jac is None:
#      67             self.x = np.asarray(x).copy()
# ---> 68             fg = self.fun(x, *args)
#      69             self.jac = fg[1]
#      70             self._value = fg[0]
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py in func(x, *args)
#     733         target = Y_multi
#     734         if solver == 'lbfgs':
# --> 735             def func(x, *args): return _multinomial_loss_grad(x, *args)[0:2]
#     736         elif solver == 'newton-cg':
#     737             def func(x, *args): return _multinomial_loss(x, *args)[0]
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py in _multinomial_loss_grad(w, X, Y, alpha, sample_weight)
#     345     grad = np.zeros((n_classes, n_features + bool(fit_intercept)),
#     346                     dtype=X.dtype)
# --> 347     loss, p, w = _multinomial_loss(w, X, Y, alpha, sample_weight)
#     348     sample_weight = sample_weight[:, np.newaxis]
#     349     diff = sample_weight * (p - Y)
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py in _multinomial_loss(w, X, Y, alpha, sample_weight)
#     296     p += intercept
#     297     p -= logsumexp(p, axis=1)[:, np.newaxis]
# --> 298     loss = -(sample_weight * Y * p).sum()
#     299     loss += 0.5 * alpha * squared_norm(w)
#     300     p = np.exp(p, p)
#
# KeyboardInterrupt:

# %%
smote = SMOTE()
X_train_resampled, y_train_resampled = smote.fit_sample(X_train_num, y_train)

# %%
X_train_num.shape
# Out:
# (44550, 9)

# %%
X_train.shape
# Out:
# (44550, 39)

# %%
X_train_resampled.shape
# Out:
# (72483, 9)

# %%
y_train.shape
# Out:
# (44550,)

# %%
y_train_resampled.shape
# Out:
# (72483,)

# %%
y_train.value_counts()
# Out:
# functional                 24161
# non functional             17146
# functional needs repair     3243
# Name: status_group, dtype: int64

# %%
y_train_resampled.value_counts()
# Out:
# functional needs repair    24161
# non functional             24161
# functional                 24161
# Name: status_group, dtype: int64

# %%
ss = StandardScaler()
X_train_resampeled_ss = ss.fit_transform(X_train_resampled)
X_test_ss = ss.fit_transform(X_test_num)

# %%
lg1 = LogisticRegression(max_iter = 1000)
lg1.fit(X_train_num, y_train)
confusion_matrix(y_test, lg1.predict(X_test_ss))
# Out:
# array([[3800, 2282, 2016],
#        [ 404,  423,  247],
#        [2478, 1956, 1244]], dtype=int64)

# %%
knn1 = KNeighborsClassifier(3)
knn1.fit(X_train_resampeled_ss, y_train_resampled)
confusion_matrix(y_test, knn1.predict(X_test_ss))
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
knn2 = KNeighborsClassifier(5)
knn2.fit(X_train_resampeled_ss, y_train_resampled)
confusion_matrix(y_test, knn2.predict(X_test_ss))
# Out:
# array([[4588, 1192, 2318],
#        [ 395,  390,  289],
#        [1850,  644, 3184]], dtype=int64)

# %%
knn3 = KNeighborsClassifier(7)
knn3.fit(X_train_resampeled_ss, y_train_resampled)
confusion_matrix(y_test, knn3.predict(X_test_ss))
# Out:
# array([[4685, 1240, 2173],
#        [ 383,  420,  271],
#        [1873,  705, 3100]], dtype=int64)

# %%
dt = DecisionTreeClassifier(random_state = 42)
dt.fit(X_train_resampeled_ss, y_train_resampled)
confusion_matrix(y_test, dt.predict(X_test_ss))
# Out:
# array([[2848, 1833, 3417],
#        [ 318,  348,  408],
#        [1816, 1040, 2822]], dtype=int64)

# %% [markdown]
# # Pipeline Scratchwork

# %%
pipe = Pipeline([('ss', StandardScaler()), ('tree', DecisionTreeClassifier(random_state = 42))])
pipe.fit(X_train_num, y_train)
# Out:
# Pipeline(steps=[('ss', StandardScaler()),
#                 ('tree', DecisionTreeClassifier(random_state=42))])

# %%
pipe.score(X_test_num, y_test)
# Out:
# 0.6676094276094277

# %%
grid = [{'tree__max_depth': [None, 2, 6, 10],
        'tree__min_samples_split': [5, 10]}]

gridsearch = GridSearchCV(estimator = pipe, param_grid = grid, scoring = 'accuracy', cv = 5)

gridsearch.fit(X_train_resampled, y_train_resampled)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('ss', StandardScaler()),
#                                        ('tree',
#                                         DecisionTreeClassifier(random_state=42))]),
#              param_grid=[{'tree__max_depth': [None, 2, 6, 10],
#                           'tree__min_samples_split': [5, 10]}],
#              scoring='accuracy')

# %%
gridsearch.score(X_train_num, y_train)
# Out:
# 0.9303030303030303

# %%
pca = PCA()
smt = SMOTE(random_state=42)
knn = KNeighborsClassifier()

# %%
pipeline = Pipeline([('smt', smt), ('pca', pca), ('knn', knn)])

# %%
pipeline.fit(X_train_num, y_train)
# Out:
# Pipeline(steps=[('smt', SMOTE(random_state=42)), ('pca', PCA()),
#                 ('knn', KNeighborsClassifier())])

# %%
y_hat = pipeline.predict(X_test_num)

# %%
print(classification_report(y_test, y_hat))
# Out:
#                          precision    recall  f1-score   support
#
#              functional       0.72      0.60      0.66      8098
# functional needs repair       0.20      0.53      0.29      1074
#          non functional       0.62      0.57      0.59      5678
#
#                accuracy                           0.58     14850
#               macro avg       0.51      0.57      0.51     14850
#            weighted avg       0.64      0.58      0.61     14850

# %% [markdown]
# # Data preprocessing

# %%
X.dropna(axis = 'columns', inplace = True)
X.drop(['date_recorded', 'ward', 'wpt_name'], axis = 1, inplace = True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .25, random_state = 42)

# %%
X_train_num, X_test_num = X_train.select_dtypes(exclude = 'object'), X_test.select_dtypes(exclude = 'object')
X_train_cat, X_test_cat = X_train.select_dtypes(include = 'object'), X_test.select_dtypes(include = 'object')

# %%
si = SimpleImputer()
X_train_num_si = pd.DataFrame(si.fit_transform(X_train_num), index = X_train_num.index, columns = X_train_num.columns)
X_test_num_si = pd.DataFrame(si.transform(X_test_num), index = X_test_num.index, columns = X_test_num.columns)

# %%
ss = StandardScaler()
X_train_num_si_ss = pd.DataFrame(ss.fit_transform(X_train_num_si), index = X_train_num_si.index, columns = X_train_num_si.columns)
X_test_num_si_ss = pd.DataFrame(ss.transform(X_test_num_si), index = X_test_num_si.index, columns = X_test_num_si.columns)

# %%
ohe = OneHotEncoder(drop = 'if_binary', sparse = False)
X_train_num_si_ss_ohe = pd.DataFrame(ohe.fit_transform(X_train_cat), index = X_train_cat.index, columns = ohe.get_feature_names(X_train_cat.columns))
X_test_num_si_ss_ohe = pd.DataFrame(ohe.transform(X_test_cat), index = X_test_cat.index, columns = ohe.get_feature_names(X_test_cat.columns))

# %%
X_train_num_si_ss_ohe_join = X_train_num_si_ss.join(X_train_num_si_ss_ohe)
X_test_num_si_ss_ohe_join = X_test_num_si_ss.join(X_test_num_si_ss_ohe)

# %%
y_train.value_counts()
# Out:
# functional                 24161
# non functional             17146
# functional needs repair     3243
# Name: status_group, dtype: int64

# %%
y_test_f = y_test

# %%
sm = SMOTE(random_state = 42)
X_train_f, y_train_f = sm.fit_sample(X_train_num_si_ss_ohe_join, y_train)

# %%
y_train_f.value_counts()
# Out:
# functional needs repair    24161
# non functional             24161
# functional                 24161
# Name: status_group, dtype: int64

# %%
lg2 = LogisticRegression(max_iter = 1000)
lg2.fit(X_train_f, y_train_f)
cross_val_score(lg2, X_train_f, y_train_f, cv = 5)
# Out:
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# array([0.67124233, 0.67731255, 0.67703663, 0.67418598, 0.67915287])

# %%
y_pred = lg2.predict(X_train_f)

# %%
lg2.score(X_train_f, y_train_f)
# Out:
# 0.6797317991804975

# %%
lg2.score(X_test_f, y_test_f)
# Out:
# 0.6414814814814814

# %%
print(classification_report(y_train_f, y_pred))
# Out:
#                          precision    recall  f1-score   support
#
#              functional       0.65      0.64      0.65     24161
# functional needs repair       0.65      0.74      0.69     24161
#          non functional       0.76      0.66      0.70     24161
#
#                accuracy                           0.68     72483
#               macro avg       0.68      0.68      0.68     72483
#            weighted avg       0.68      0.68      0.68     72483

# %%
g1 = {
    'max_iter': [ 100, 1000, 10000],
    'C': [ 0.1, 1.0, 10, 100],
    'tol': [ 10, 100, 1000],
}

gs1 = GridSearchCV(LogisticRegression(), g1)
gs1.fit(X_train_f, y_train_f)
# Out:
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid={'C': [0.1, 1.0, 10, 100],
#                          'max_iter': [100, 1000, 10000],
#                          'tol': [10, 100, 1000]})

# %%
gs1.best_estimator_
# Out:
# LogisticRegression(C=10, max_iter=1000, tol=10)

# %%
gs1.best_score_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-181-34dff1635f3b> in <module>
# ----> 1 gs1.best_score_
#
# NameError: name 'gs1' is not defined

# %%
g2 = {
    'n_neighbors': [5, 7, 9],
    'weights': ['uniform', 'distance'],
    'p' : [1,2]
}

gs2 = GridSearchCV(KNeighborsClassifier(), g2)
gs2.fit(X_train_f, y_train_f)
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [5, 7, 9], 'p': [1, 2],
#                          'weights': ['uniform', 'distance']})

# %%
gs2.best_estimator_
# Out:
# KNeighborsClassifier(p=1, weights='distance')

# %%
gs2.best_score_
# Out:
# 0.8322645948594678

# %%
gs2.best_estimator_.score(X_test_f, y_test_f)
# Out:
# 0.7494949494949495

# %%
g3 = {
    'max_depth': [5, 7, 9],
    'min_samples_split': [2, 3, 4],
    'min_samples_leaf' : [1,2,3]
}

gs3 = GridSearchCV(DecisionTreeClassifier(), g3)
gs3.fit(X_train_f, y_train_f)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [5, 7, 9], 'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 3, 4]})

# %%
gs3.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=9, min_samples_split=3)

# %%
gs3.best_score_
# Out:
# 0.6541672338845779

# %%
gs3.best_estimator_.score(X_test_f, y_test_f)
# Out:
# 0.6175757575757576

# %%
from sklearn.ensemble import RandomForestClassifier

g4 = {
    'max_depth': [ 2, 5, 10 ],
    'n_estimators': [ 100, 1000, 2000]
}

gs4 = GridSearchCV(RandomForestClassifier(), g4)
gs4.fit(X_train_f, y_train_f)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [2, 5, 10],
#                          'n_estimators': [100, 1000, 2000]})

# %%
gs4.best_estimator_
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=2000)

# %%
gs4.best_score_
# Out:
# 0.7201414464452643

# %%
gs4.best_estimator_.score(X_test_f, y_test_f)
# Out:
# 0.6769023569023569

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
g5 = {
    'n_estimators': [ 10, 100, 1000],
    'max_depth': [None, 10, 100],
    'min_samples_split': [2,3,4],
    'min_samples_leaf': [1,2,3]
}

gs5 = GridSearchCV(ExtraTreesClassifier(), g5)
gs5.fit(X_train_f, y_train_f)

# %% [markdown]
# # Visualizations

# %%
sns.set(context = 'notebook', style = 'whitegrid')

# %%
dv = df.copy()

# %%
dv.columns
# Out:
# Index(['amount_tsh', 'date_recorded', 'funder', 'gps_height', 'installer',
#        'longitude', 'latitude', 'wpt_name', 'num_private', 'basin',
#        'subvillage', 'region', 'region_code', 'district_code', 'lga', 'ward',
#        'population', 'public_meeting', 'recorded_by', 'scheme_management',
#        'scheme_name', 'permit', 'construction_year', 'extraction_type',
#        'extraction_type_group', 'extraction_type_class', 'management',
#        'management_group', 'payment', 'payment_type', 'water_quality',
#        'quality_group', 'quantity', 'quantity_group', 'source', 'source_type',
#        'source_class', 'waterpoint_type', 'waterpoint_type_group', 'target'],
#       dtype='object')

# %%
count = dv[dv.construction_year != 0]
sns.displot(data = count, x = 'construction_year', kind = 'hist', stat = 'count', hue = 'target', multiple = 'stack', binwidth = 2, element = 'bars', kde = False, palette = 'flare', aspect = 1.7)

plt.xlim(1960, 2015)
# Out:
# (1960.0, 2015.0)

# %%
dv['extraction_type_class'].value_counts()
# Out:
# gravity         26780
# handpump        16456
# other            6430
# submersible      6179
# motorpump        2987
# rope pump         451
# wind-powered      117
# Name: extraction_type_class, dtype: int64

# %%
dv[df['target'] == 'functional needs repair']['extraction_type_class'].value_counts()
# Out:
# gravity         2701
# handpump         995
# submersible      253
# other            206
# motorpump        138
# rope pump         17
# wind-powered       7
# Name: extraction_type_class, dtype: int64

# %%
count_rfun = dv[df['target'] == 'functional needs repair']['extraction_type_class']
count_nfun = pd.concat([dv[df['target'] == 'non functional']['extraction_type_class'], count_rfun])
count_fun = pd.concat([dv[df['target'] == 'functional']['extraction_type_class'], count_nfun])

# %%
plt.figure(figsize = (10,5))
order = ['gravity', 'handpump', 'other', 'submersible', 'motorpump']
sns.countplot(y = count_fun, orient = 'v', color = '#d47d6f', order = order, alpha = 0.8)
sns.countplot(y = count_nfun, orient = 'v', color = '#b1516e', order = order, alpha = 0.8)
sns.countplot(y = count_rfun, orient = 'v', color = '#7b3b6b', order = order, alpha = 0.8)

# %%
sns.countplot(y = count_fun, orient = 'v')

# %%
len(dv['population'].value_counts())
# Out:
# 1049

# %%
dv['population'].describe()
# Out:
# count    59400.000000
# mean       179.909983
# std        471.482176
# min          0.000000
# 25%          0.000000
# 50%         25.000000
# 75%        215.000000
# max      30500.000000
# Name: population, dtype: float64

# %%
pop = df[dv['population'] > 0]

# %%
sns.boxplot(pop['population'])
# Out:
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
pop.population
# Out:
# id
# 69572    109
# 8776     280
# 34310    250
# 67743     58
# 9944       1
#         ...
# 44885    210
# 11164     89
# 60739    125
# 27263     56
# 26348    150
# Name: population, Length: 38019, dtype: int64

# %%
dv['water_quality'].value_counts()
# Out:
# soft                  50818
# salty                  4856
# unknown                1876
# milky                   804
# coloured                490
# salty abandoned         339
# fluoride                200
# fluoride abandoned       17
# Name: water_quality, dtype: int64

# %%
dv['quality_group'].value_counts()
# Out:
# good        50818
# salty        5195
# unknown      1876
# milky         804
# colored       490
# fluoride      217
# Name: quality_group, dtype: int64

# %%
dv['source'].value_counts()
# Out:
# spring                  17021
# shallow well            16824
# machine dbh             11075
# river                    9612
# rainwater harvesting     2295
# hand dtw                  874
# lake                      765
# dam                       656
# other                     212
# unknown                    66
# Name: source, dtype: int64

# %%
dv['source_type'].value_counts()
# Out:
# spring                  17021
# shallow well            16824
# borehole                11949
# river/lake              10377
# rainwater harvesting     2295
# dam                       656
# other                     278
# Name: source_type, dtype: int64

# %%
dv['source_class'].value_counts()
# Out:
# groundwater    45794
# surface        13328
# unknown          278
# Name: source_class, dtype: int64

# %%
cats = dv[dv['source_class'] != 'unknown']

# %%
cats['source_class'].value_counts()
# Out:
# groundwater    45794
# surface        13328
# Name: source_class, dtype: int64

# %%
sns.catplot(data = cats, x = 'target', kind = 'count', row = 'source_class', col = 'quality_group', sharey = False)

# %%
percents = []
for i in cats['source_class'].unique():
    for j in cats['quality_group'].unique():
        tmp = cats[(cats['source_class'] == i) & (cats['quality_group'] == j)]
        percent_sum = tmp.target.value_counts().sort_index().values.sum()
        percent_name = tmp.target.value_counts().sort_index()
        percent = tmp.target.value_counts().sort_index().values/ percent_sum
        if (len(percent) < 3):
            percent = np.concatenate((percent, [0]))
        percents.append([i,j, 'functional', percent[0]])
        percents.append([i,j, 'non functional', percent[1]])
        percents.append([i,j, 'functional needs repair', percent[2]]        )

# %%
pf = pd.DataFrame(percents, columns = ['source_class', 'quality_group', 'target', 'percentage'])
pf.head()
# Out:
#   source_class quality_group                   target  percentage
# 0  groundwater          good               functional    0.569751
# 1  groundwater          good           non functional    0.062734
# 2  groundwater          good  functional needs repair    0.367514
# 3  groundwater         milky               functional    0.542245
# 4  groundwater         milky           non functional    0.017654

# %%
sns.catplot(data = pf, x = 'target', y = 'percentage', kind = 'bar', row = 'source_class', col = 'quality_group', palette = 'flare')

# %%
pf['quality_group'].value_counts().index()
# Out:
# Index(['salty', 'colored', 'fluoride', 'good', 'unknown', 'milky'], dtype='object')

# %%
pf['quality_group'].value_counts()
# Out:
# salty       6
# colored     6
# fluoride    6
# good        6
# unknown     6
# milky       6
# Name: quality_group, dtype: int64

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x = 'longitude', y = 'latitude', hue = 'target', data = dv)
plt.xlim(25, 45)
plt.ylim(-12, 0)
plt.show()

# %%
dv['population'].value_counts()
# Out:
# 0       21381
# 1        7025
# 200      1940
# 150      1892
# 250      1681
#         ...
# 3241        1
# 1960        1
# 1685        1
# 2248        1
# 1439        1
# Name: population, Length: 1049, dtype: int64

# %%
dv['amount_tsh'].value_counts()
# Out:
# 0.0         41639
# 500.0        3102
# 50.0         2472
# 1000.0       1488
# 20.0         1463
#             ...
# 8500.0          1
# 6300.0          1
# 220.0           1
# 138000.0        1
# 12.0            1
# Name: amount_tsh, Length: 98, dtype: int64

# %%
sns.displot(data = dv, x = 'amount_tsh', kind = 'hist', bins = 100)

# %%
sns.displot(data = df, y = 'amount_tsh', x = 'population', kind = 'kde', height = 10, aspect = 1, color = '#663777', palette = 'flare')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-144-b7cc90779018> in <module>
# ----> 1 sns.displot(data = df, y = 'amount_tsh', x = 'population', kind = 'kde', height = 10, aspect = 1, color = '#663777', palette = 'flare')
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\seaborn\distributions.py in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2252
#    2253             _assign_default_kwargs(kde_kws, p.plot_bivariate_density, kdeplot)
# -> 2254             p.plot_bivariate_density(**kde_kws)
#    2255
#    2256     elif kind == "ecdf":
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\seaborn\distributions.py in plot_bivariate_density(self, common_norm, fill, levels, thresh, color, legend, cbar, cbar_ax, cbar_kws, estimate_kws, **contour_kws)
#    1182                 xx, yy, density,
#    1183                 levels=draw_levels[key],
# -> 1184                 **contour_kws,
#    1185             )
#    1186
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\matplotlib\axes\_axes.py in contour(self, *args, **kwargs)
#    6335     def contour(self, *args, **kwargs):
#    6336         kwargs['filled'] = False
# -> 6337         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6338         self._request_autoscale_view()
#    6339         return contours
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\matplotlib\contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, *args, **kwargs)
#     820         self._transform = kwargs.pop('transform', None)
#     821
# --> 822         kwargs = self._process_args(*args, **kwargs)
#     823         self._process_levels()
#     824
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\matplotlib\contour.py in _process_args(self, *args, **kwargs)
#    1417                 self._corner_mask = mpl.rcParams['contour.corner_mask']
#    1418
# -> 1419             x, y, z = self._contour_args(args, kwargs)
#    1420
#    1421             _mask = ma.getmask(z)
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\matplotlib\contour.py in _contour_args(self, args, kwargs)
#    1488                                  'masked')
#    1489             self.zmin = float(z.min())
# -> 1490         self._contour_level_args(z, args)
#    1491         return (x, y, z)
#    1492
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\matplotlib\contour.py in _contour_level_args(self, z, args)
#    1172
#    1173         if len(self.levels) > 1 and np.min(np.diff(self.levels)) <= 0.0:
# -> 1174             raise ValueError("Contour levels must be increasing")
#    1175
#    1176     def _process_levels(self):
#
# ValueError: Contour levels must be increasing

# %%
sns.kdeplot(data = dv, x = 'amount_tsh', y = 'population', hue = 'target', size = 'target', palette = 'flare')
plt.xlim(-1000,50000)
plt.ylim(-1000, 10000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-142-b6be5afcb6cc> in <module>
# ----> 1 sns.kdeplot(data = dv, x = 'amount_tsh', y = 'population', hue = 'target', size = 'target', palette = 'flare')
#       2 plt.xlim(-1000,50000)
#       3 plt.ylim(-1000, 10000)
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\seaborn\distributions.py in kdeplot(x, y, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, weights, hue, palette, hue_order, hue_norm, multiple, common_norm, common_grid, levels, thresh, bw_method, bw_adjust, log_scale, color, fill, data, data2, **kwargs)
#    1751             cbar_kws=cbar_kws,
#    1752             estimate_kws=estimate_kws,
# -> 1753             **kwargs,
#    1754         )
#    1755
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\seaborn\distributions.py in plot_bivariate_density(self, common_norm, fill, levels, thresh, color, legend, cbar, cbar_ax, cbar_kws, estimate_kws, **contour_kws)
#    1182                 xx, yy, density,
#    1183                 levels=draw_levels[key],
# -> 1184                 **contour_kws,
#    1185             )
#    1186
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\matplotlib\axes\_axes.py in contour(self, *args, **kwargs)
#    6335     def contour(self, *args, **kwargs):
#    6336         kwargs['filled'] = False
# -> 6337         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6338         self._request_autoscale_view()
#    6339         return contours
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\matplotlib\contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, *args, **kwargs)
#     820         self._transform = kwargs.pop('transform', None)
#     821
# --> 822         kwargs = self._process_args(*args, **kwargs)
#     823         self._process_levels()
#     824
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\matplotlib\contour.py in _process_args(self, *args, **kwargs)
#    1417                 self._corner_mask = mpl.rcParams['contour.corner_mask']
#    1418
# -> 1419             x, y, z = self._contour_args(args, kwargs)
#    1420
#    1421             _mask = ma.getmask(z)
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\matplotlib\contour.py in _contour_args(self, args, kwargs)
#    1488                                  'masked')
#    1489             self.zmin = float(z.min())
# -> 1490         self._contour_level_args(z, args)
#    1491         return (x, y, z)
#    1492
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\matplotlib\contour.py in _contour_level_args(self, z, args)
#    1172
#    1173         if len(self.levels) > 1 and np.min(np.diff(self.levels)) <= 0.0:
# -> 1174             raise ValueError("Contour levels must be increasing")
#    1175
#    1176     def _process_levels(self):
#
# ValueError: Contour levels must be increasing

# %%
sns.histplot(data = dv, x = 'amount_tsh', y = 'population', hue = 'target', size = 'target', palette = 'flare')
plt.xlim(-1000,50000)
plt.ylim(-1000, 10000)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-143-612ed5b45ef4> in <module>
# ----> 1 sns.histplot(data = dv, x = 'amount_tsh', y = 'population', hue = 'target', size = 'target', palette = 'flare')
#       2 plt.xlim(-1000,50000)
#       3 plt.ylim(-1000, 10000)
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\seaborn\distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1450             cbar_kws=cbar_kws,
#    1451             estimate_kws=estimate_kws,
# -> 1452             **kwargs,
#    1453         )
#    1454
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\seaborn\distributions.py in plot_bivariate_histogram(self, common_bins, common_norm, thresh, pthresh, pmax, color, legend, cbar, cbar_ax, cbar_kws, estimate_kws, **plot_kws)
#     748             sub_data = sub_data.dropna()
#     749             sub_heights, _ = estimator(
# --> 750                 sub_data["x"], sub_data["y"], sub_data.get("weights", None)
#     751             )
#     752             full_heights.append(sub_heights)
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\seaborn\_statistics.py in __call__(self, x1, x2, weights)
#     371             return self._eval_univariate(x1, weights)
#     372         else:
# --> 373             return self._eval_bivariate(x1, x2, weights)
#     374
#     375
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\seaborn\_statistics.py in _eval_bivariate(self, x1, x2, weights)
#     321
#     322         hist, _, _ = np.histogram2d(
# --> 323             x1, x2, bin_edges, weights=weights, density=density
#     324         )
#     325
#
# <__array_function__ internals> in histogram2d(*args, **kwargs)
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\numpy\lib\twodim_base.py in histogram2d(x, y, bins, range, normed, weights, density)
#     711         xedges = yedges = asarray(bins)
#     712         bins = [xedges, yedges]
# --> 713     hist, edges = histogramdd([x, y], bins, range, normed, weights, density)
#     714     return hist, edges[0], edges[1]
#     715
#
# <__array_function__ internals> in histogramdd(*args, **kwargs)
#
# Y:\Users\awyeh\anaconda3\envs\learn-env\lib\site-packages\numpy\lib\histograms.py in histogramdd(sample, bins, range, normed, weights, density)
#    1098
#    1099     # This preserves the (bad) behavior observed in gh-7845, for now.
# -> 1100     hist = hist.astype(float, casting='safe')
#    1101
#    1102     # Remove outliers (indices 0 and -1 for each dimension).
#
# MemoryError: Unable to allocate 7.05 GiB for an array with shape (341408, 2770) and data type float64

# %%
sns.scatterplot(data = dv, x = 'amount_tsh', y = 'population', hue = 'target', size = 'target', palette = 'flare')
plt.xlim(-1000,50000)
plt.ylim(-1000, 10000)
# Out:
# (-1000.0, 10000.0)

# %%
sns.relplot(data = dv, x = 'amount_tsh', y = 'population', col = 'target')
plt.xlim(1,50000)
plt.ylim(1, 10000)
# Out:
# (1.0, 10000.0)

# %%
sns.relplot(data = dv, x = 'amount_tsh', y = 'population', col = 'target', kind = 'line', sort = False)
plt.xlim(1,50000)
plt.ylim(1, 10000)
# Out:
# (1.0, 10000.0)
